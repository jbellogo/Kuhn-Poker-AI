# %%
from itertools import permutations

# %%
def factorial(n):
    ans = 1
    for i in range(1, n+1):
        ans*=i
    return ans

def nPk(n, k):
    if k==0:
        return 1
    return factorial(n)/factorial(k)

def multinomial(n, a, b, c):
    # only computes trinomial (n chose a,b,c)
    return factorial(n)/(factorial(a)*factorial(b)*factorial(c))

# %%
ans = 0
num_as = 2

for i in range(4,33):
    b_bound = min(i-3, 10)+1
    print(f"3rd A index = {i}")

    for num_bs in range(1, b_bound):
        print(f" number of B's = {num_bs}")

        gap_size = i-1
        num_cs =  gap_size - num_as-num_bs
        assert(num_as+num_bs+num_cs==gap_size)
        factor=multinomial(gap_size, num_as, num_bs, num_cs)
        factor*=12
        factor*=nPk(10, num_bs)
        # print(factor)
        factor*=nPk(20, num_cs)
        # print(factor)
        factor*=factorial(35-i)
        ans+=factor

ans
# Out:
# 3rd A index = 4
#  number of B's = 1
# 3rd A index = 5
#  number of B's = 1
#  number of B's = 2
# 3rd A index = 6
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
# 3rd A index = 7
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
# 3rd A index = 8
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
# 3rd A index = 9
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
# 3rd A index = 10
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
# 3rd A index = 11
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
# 3rd A index = 12
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
# 3rd A index = 13
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 14
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 15
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 16
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 17
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 18
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 19
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 20
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 21
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 22
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 23
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 24
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 25
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 26
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 27
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 28
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 29
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 30
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 31
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3rd A index = 32
#  number of B's = 1
#  number of B's = 2
#  number of B's = 3
#  number of B's = 4
#  number of B's = 5
#  number of B's = 6
#  number of B's = 7
#  number of B's = 8
#  number of B's = 9
#  number of B's = 10
# 3.6674386838743304e+59

# %%
denom = factorial(35)
denom
# Out:
# 10333147966386144929666651337523200000000

# %%
ans/denom
# Out:
# 3.549197878327643e+19

# %%
# # try computing the explicit sets
# These ranges don't work because 35! is too large.
# ranges = {'A': 5, 'B': 10, 'C': 20}

ranges = {'A': 5, 'B': 10, 'C': 20}

A = ['A'+ str(i) for i in range(1, ranges['A']+1)]
B = ['B'+ str(i) for i in range(1, ranges['B']+1)]
C = ['C'+ str(i) for i in range(1, ranges['C']+1)]

# %%
N = A +B +C

# %%
N
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'B7',
#  'B8',
#  'B9',
#  'B10',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'C6',
#  'C7',
#  'C8',
#  'C9',
#  'C10',
#  'C11',
#  'C12',
#  'C13',
#  'C14',
#  'C15',
#  'C16',
#  'C17',
#  'C18',
#  'C19',
#  'C20']

# %%
all_perms = permutations(N)

# %%
# for permutation in all_perms:
#     print(permutation)

# %%
shapleyAnominator = 0
for permutation in all_perms:
    left_As_count=0
    left_Bs_count=0
    for shareholder in permutation:
        if shareholder == "A5":
            break
        else:
            if shareholder[0] == "A":
                left_As_count+=1
            if shareholder[0] == "B":
                left_Bs_count+=1
    if left_As_count==2 and left_Bs_count>0:
        shapleyAnominator += 1

# %%
shapleyAnominator
# Out:
# 0

# %%
print("Summation of:")
for i in range(3, 34):
    print(f" C({i-1}, ({2, i-3})) * P(30, {i-3}) ")
# Out:
# Summation of:
#  C(2, ((2, 0))) * P(30, 0)
#  C(3, ((2, 1))) * P(30, 1)
#  C(4, ((2, 2))) * P(30, 2)
#  C(5, ((2, 3))) * P(30, 3)
#  C(6, ((2, 4))) * P(30, 4)
#  C(7, ((2, 5))) * P(30, 5)
#  C(8, ((2, 6))) * P(30, 6)
#  C(9, ((2, 7))) * P(30, 7)
#  C(10, ((2, 8))) * P(30, 8)
#  C(11, ((2, 9))) * P(30, 9)
#  C(12, ((2, 10))) * P(30, 10)
#  C(13, ((2, 11))) * P(30, 11)
#  C(14, ((2, 12))) * P(30, 12)
#  C(15, ((2, 13))) * P(30, 13)
#  C(16, ((2, 14))) * P(30, 14)
#  C(17, ((2, 15))) * P(30, 15)
#  C(18, ((2, 16))) * P(30, 16)
#  C(19, ((2, 17))) * P(30, 17)
#  C(20, ((2, 18))) * P(30, 18)
#  C(21, ((2, 19))) * P(30, 19)
#  C(22, ((2, 20))) * P(30, 20)
#  C(23, ((2, 21))) * P(30, 21)
#  C(24, ((2, 22))) * P(30, 22)
#  C(25, ((2, 23))) * P(30, 23)
#  C(26, ((2, 24))) * P(30, 24)
#  C(27, ((2, 25))) * P(30, 25)
#  C(28, ((2, 26))) * P(30, 26)
#  C(29, ((2, 27))) * P(30, 27)
#  C(30, ((2, 28))) * P(30, 28)
#  C(31, ((2, 29))) * P(30, 29)
#  C(32, ((2, 30))) * P(30, 30)
